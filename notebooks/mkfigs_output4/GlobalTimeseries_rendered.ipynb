# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [12]</a>'.</span>

# %% [markdown]
# # Plotting Key Global Timeseries in ACCESS-OM3
#
# This notebook uses the initial spinup simulation of ACCESS-OM3.

# %%
#parameters

### USER EDIT start
esm_file='/g/data/ol01/access-om3-output/access-om3-025/MC_25km_jra_ryf-1.0-beta/experiment_datastore.json'
dpi=300
### USER EDIT stop

import os
from matplotlib import rcParams
# %matplotlib inline
rcParams['figure.dpi']= dpi

plotfolder=f"/g/data/{os.environ['PROJECT']}/{os.environ['USER']}/access-om3-paper-figs/"
os.makedirs(plotfolder, exist_ok=True)

 # a similar cell under this means it's being run in batch
print("ESM datastore path: ",esm_file)
print("Plot folder path: ",plotfolder)
# Out:
# ESM datastore path:  /g/data/ol01/access-om3-output/access-om3-025/MC_25km_jra_ryf-1.0-beta/experiment_datastore.json
# Plot folder path:  /g/data/tm70/cyb561/access-om3-paper-figs/

# %%
# Parameters
esm_file = "/g/data/ol01/access-om3-output/access-om3-025/25km-iaf-test-for-AK-expt-7df5ef4c/datastore.json"
plotfolder = "/g/data/tm70/cyb561/access-om3-paper-1/notebooks/mkfigs_output4/"

# %%
import intake
from dask.distributed import Client
import matplotlib.pyplot as plt
import cmocean as cm
import cftime

# %%
client = Client(threads_per_worker=1)
print(client.dashboard_link)
# Out:
# http://127.0.0.1:8787/status

# %% [markdown]
# ## Load ACCESS-OM3 data from ESM datastore

# %%
#datastore_path = "/g/data/ol01/access-om3-output/access-om3-025/MC_25km_jra_ryf-1.0-beta/experiment_datastore.json"

datastore = intake.open_esm_datastore(
    esm_file,
    columns_with_iterables=[
        "variable",
        "variable_long_name",
        "variable_standard_name",
        "variable_cell_methods",
        "variable_units"
    ]
)

# %%
tosga = datastore.search(variable="tosga").to_dask(
    xarray_open_kwargs = dict(
        chunks={"time": -1},
        decode_timedelta=True
    )
)['tosga'].resample(time = '1YE').mean('time').load()
sosga = datastore.search(variable="sosga").to_dask(
    xarray_open_kwargs = dict(
        chunks={"time": -1},
        decode_timedelta=True
    )
)['sosga'].resample(time = '1YE').mean('time').load()

thetaoga = datastore.search(variable="thetaoga").to_dask(
    xarray_open_kwargs = dict(
        chunks={"time": -1},
        decode_timedelta=True
    )
)['thetaoga'].resample(time = '1YE').mean('time').load()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:321: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:321: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:321: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')

# %% [markdown]
# ## Load ACCESS-OM2 data from ACCESS-NRI Catalog

# %%
catalog = intake.cat.access_nri

# %%
var = catalog['025deg_jra55_ryf9091_gadi'].search(variable='temp_global_ave',frequency="1mon")
temp_global_ave=var.to_dask(
            xarray_open_kwargs=dict(
            chunks={"time": -1},
            decode_timedelta=True,
            use_cftime=True)
)['temp_global_ave'].sel(time=slice(cftime.datetime(1900, 1, 1,calendar='noleap'), cftime.datetime(1950, 12, 31,calendar='noleap'))).resample(time = '1YE').mean('time').load()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:321: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')

# %%
var = catalog['025deg_jra55_ryf9091_gadi'].search(variable='temp_surface_ave',frequency="1mon")
temp_surface_ave=var.to_dask(
            xarray_open_kwargs=dict(
            chunks={"time": -1},
            decode_timedelta=True,
            use_cftime=True)
)['temp_surface_ave'].sel(time=slice(cftime.datetime(1900, 1, 1,calendar='noleap'), cftime.datetime(1950, 12, 31,calendar='noleap'))).resample(time = '1YE').mean('time').load()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:321: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')

# %%
var = catalog['025deg_jra55_ryf9091_gadi'].search(variable='salt_surface_ave',frequency="1mon")
salt_surface_ave=var.to_dask(
            xarray_open_kwargs=dict(
            chunks={"time": -1},
            decode_timedelta=True,
            use_cftime=True)
)['salt_surface_ave'].sel(time=slice(cftime.datetime(1900, 1, 1,calendar='noleap'), cftime.datetime(1950, 12, 31,calendar='noleap'))).resample(time = '1YE').mean('time').load()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:321: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')

# %%
var = catalog['025deg_jra55_ryf9091_gadi'].search(variable='ke_tot',frequency="1mon")
ke_tot=var.to_dask(
            xarray_open_kwargs=dict(
            chunks={"time": -1},
            decode_timedelta=True,
            use_cftime=True)
)['ke_tot'].sel(time=slice(cftime.datetime(1900, 1, 1,calendar='noleap'), cftime.datetime(1950, 12, 31,calendar='noleap'))).resample(time = '1YE').mean('time').load()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:321: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')

# %% [markdown]
# ## Plot Timeseries

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
plt.figure(figsize=(12,8))

plt.subplot(221)
temp_global_ave.plot(label="ACCESS-OM2")
thetaoga.plot(label="ACCESS-OM3")
plt.legend()
plt.ylabel('Temperature (°C)')
plt.xlabel('')
plt.title('(a) Global average temperature')

plt.subplot(222)
temp_surface_ave.plot(label="ACCESS-OM2")
tosga.plot(label="ACCESS-OM3")
plt.ylabel('')
plt.xlabel('')
plt.title('(b) Global average sea surface temperature')

plt.subplot(223)
salt_surface_ave.plot(label="ACCESS-OM2")
sosga.plot(label="ACCESS-OM3")
plt.ylabel('Salinity (g/kg)')
plt.title('(c) Global average sea surface salinity')


plt.subplot(224)
ke_tot.plot(label="ACCESS-OM2")
#no_ke_diagnostic_for_om3.plot(label="ACCESS-OM3")
plt.ylabel('KE (m^2/s^2)')
plt.title('(d) Global average kinetic energy')
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/xarray/plot/dataarray_plot.py:512: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   primitive = ax.plot(xplt_val, yplt_val, *args, **kwargs)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       3 plt.subplot(221)
#       4 temp_global_ave.plot(label="ACCESS-OM2")
# ----> 5 thetaoga.plot(label="ACCESS-OM3")
#       6 plt.legend()
#       7 plt.ylabel('Temperature (°C)')
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/xarray/plot/accessor.py:48, in DataArrayPlotAccessor.__call__(self, **kwargs)
#      46 @functools.wraps(dataarray_plot.plot, assigned=("__doc__", "__annotations__"))
#      47 def __call__(self, **kwargs) -> Any:
# ---> 48     return dataarray_plot.plot(self._da, **kwargs)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/xarray/plot/dataarray_plot.py:310, in plot(darray, row, col, col_wrap, ax, hue, subplot_kws, **kwargs)
#     306     plotfunc = hist
#     308 kwargs["ax"] = ax
# --> 310 return plotfunc(darray, **kwargs)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/xarray/plot/dataarray_plot.py:512, in line(darray, row, col, figsize, aspect, size, ax, hue, x, y, xincrease, yincrease, xscale, yscale, xticks, yticks, xlim, ylim, add_legend, _labels, *args, **kwargs)
#     508 ylabel = label_from_attrs(yplt, extra=y_suffix)
#     510 _ensure_plottable(xplt_val, yplt_val)
# --> 512 primitive = ax.plot(xplt_val, yplt_val, *args, **kwargs)
#     514 if _labels:
#     515     if xlabel is not None:
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)
#    1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/matplotlib/axes/_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/matplotlib/axes/_base.py:489, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     486     x, y = index_of(xy[-1])
#     488 if axes.xaxis is not None:
# --> 489     axes.xaxis.update_units(x)
#     490 if axes.yaxis is not None:
#     491     axes.yaxis.update_units(y)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/matplotlib/axis.py:1759, in Axis.update_units(self, data)
#    1756     self.set_units(default)
#    1758 elif neednew:
# -> 1759     self._update_axisinfo()
#    1760 self.stale = True
#    1761 return True
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/matplotlib/axis.py:1771, in Axis._update_axisinfo(self)
#    1768 if self._converter is None:
#    1769     return
# -> 1771 info = self._converter.axisinfo(self.units, self)
#    1773 if info is None:
#    1774     return
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/matplotlib/dates.py:1828, in _SwitchableDateConverter.axisinfo(self, *args, **kwargs)
#    1827 def axisinfo(self, *args, **kwargs):
# -> 1828     return self._get_converter().axisinfo(*args, **kwargs)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/matplotlib/dates.py:1745, in DateConverter.axisinfo(self, unit, axis)
#    1737 """
#    1738 Return the `~matplotlib.units.AxisInfo` for *unit*.
#    1739
#    1740 *unit* is a `~datetime.tzinfo` instance or None.
#    1741 The *axis* argument is required but not used.
#    1742 """
#    1743 tz = unit
# -> 1745 majloc = AutoDateLocator(tz=tz,
#    1746                          interval_multiples=self._interval_multiples)
#    1747 majfmt = AutoDateFormatter(majloc, tz=tz)
#    1748 datemin = datetime.date(1970, 1, 1)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/matplotlib/dates.py:1279, in AutoDateLocator.__init__(self, tz, minticks, maxticks, interval_multiples)
#    1254 def __init__(self, tz=None, minticks=5, maxticks=None,
#    1255              interval_multiples=True):
#    1256     """
#    1257     Parameters
#    1258     ----------
#    (...)
#    1277         at 6 hour intervals.
#    1278     """
# -> 1279     super().__init__(tz=tz)
#    1280     self._freq = YEARLY
#    1281     self._freqs = [YEARLY, MONTHLY, DAILY, HOURLY, MINUTELY,
#    1282                    SECONDLY, MICROSECONDLY]
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/matplotlib/dates.py:1078, in DateLocator.__init__(self, tz)
#    1071 def __init__(self, tz=None):
#    1072     """
#    1073     Parameters
#    1074     ----------
#    1075     tz : str or `~datetime.tzinfo`, default: :rc:`timezone`
#    1076         Ticks timezone. If a string, *tz* is passed to `dateutil.tz`.
#    1077     """
# -> 1078     self.tz = _get_tzinfo(tz)
#
# File /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/matplotlib/dates.py:224, in _get_tzinfo(tz)
#     222 if isinstance(tz, datetime.tzinfo):
#     223     return tz
# --> 224 raise TypeError(f"tz must be string or tzinfo subclass, not {tz!r}.")
#
# TypeError: tz must be string or tzinfo subclass, not ('noleap', 'days since 2000-01-01', <class 'cftime._cftime.DatetimeNoLeap'>).

# %%
client.close()
