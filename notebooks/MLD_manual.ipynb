# %% [markdown]
# # Maximum mixed layer depth in ACCESS-OM3, calculated manually
#
# Related issue: https://github.com/ACCESS-Community-Hub/access-om3-paper-1/issues/38
#
# Requires access to `/g/data/av17`
#
# **Note from Katja:** This notebooks calculates the MLD manually in OM3 and OM2 from temperature and salinity, etc, so that we can correctly compare them (since as far as I know, the mld diagnostics are calculated slightly differently within OM2 vs OM3).

# %%
# These first two cells must be in all notebooks!
# It allows us to run all the notebooks at once, this cell has a tag "parameters" which allows us to pass in 
# arguments externally using papermill (see mkfigs.sh for details)

# Set esm_file to the datastore for the main experiment of interest
esm_file = "/g/data/ol01/outputs/access-om3-25km/MC_25km_jra_iaf+wombatlite-test4-d28e0359/datastore.json"

## Note on the below: every value that might change between experiments lives here, tagged so papermill can override it from the command line without editing the notebook.

# CMOR names for the two variables we need to build MLD from scratch.
temp_standard_name = "thetao"   # CMOR equivalent of native "temp" (Potential Temperature, degC)
salt_standard_name = "so"       # CMOR equivalent of native "salt" (Salinity, psu)

# Fallback variable names if the catalog doesn't expose the CMOR name directly,
temp_fallback_names = ["temp", "thetao"]
salt_fallback_names = ["salt", "so"]

# Frequency depends on the datastore you're using
data_frequency = "1mon"

# MLD calculation criterion (delta-sigma0 method)
delta_rho = 0.03      # kg/m3 density threshold
ref_depth = 10.0      # reference depth in metres

# Averaging window configuration (last N years of the run, by default)
averaging_mode = "last_n_years"   # or "full_period" / "fixed_period"
averaging_last_n_years = 10
averaging_start_date = None
averaging_end_date = None

# Path to the observational MLD product for comparison
obs_file = "/g/data/av17/access-nri/OM3/MLD-DeBoyerMontegut2023/mld_dr003_ref10m_v2023.nc"

# papermill settings. *No need to modify these if running interactively.* 
papermill = False                      # `cwd` and `nbname` will be populated by papermill.
cwd = None                             # current working directory 
nbname = None                          # notebook name

# %%
if not papermill: 
    import nci_ipynb, os  # requires conda/analysis3-26.03 or later
    cwd = nci_ipynb.dir()
    nbname = nci_ipynb.name()
    os.chdir(cwd)
import mkfigs_bootstrap  # noqa: adds external/access-model-mkfigs/src to sys.path (stop-gap)
from mkfigs import MkmdWriter
mkmd = MkmdWriter(esm_file, nbname, str(cwd), pm=papermill)

# %%
# Tried to make it so we can look at OM3 or CM3 
from exptdata_access import get_experiment_info, guess_experiment_from_esm_file
from model_agnostic import get_lon_lat_from_catalog, select_variable
# Infer model information from the datastore path
expt_key, info = guess_experiment_from_esm_file(esm_file)
model_name = info["model"]             # OM3 or CM3

# %%
import xarray as xr
import cf_xarray as cfxr
import cf_xarray.units
import pint_xarray
from pint import application_registry as ureg
import intake
import gsw
import numpy as np
import matplotlib.pyplot as plt
import cmocean as cm
import warnings
xr.set_options(keep_attrs=True);  # cf_xarray works best when xarray keeps attributes by default

# Silence the noisy-but-harmless warnings 
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
from dask.distributed import Client
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:44909' processes=7 threads=28, memory=125.19 GiB>

# %% [markdown]
# ### Defining MLD calculation

# %%
def calculate_mld_profile_om3(depth, temperature, salinity,
                               delta_rho=0.03, ref_depth=10.0,
                               lon=None, lat=None):
    """
    Compute mixed layer depth for a single water column using the
    delta-sigma0 method (Boyer Montegut et al.).

    Parameters
    ----------
    temperature : Potential Temperature in Celsius
    salinity    : Practical Salinity in PSU
    depth       : in metres, positive downward
    """
    # Drop any level where T, S, or depth is missing (land / below bathymetry)
    valid = np.isfinite(temperature) & np.isfinite(salinity) & np.isfinite(depth)
    if valid.sum() < 2:
        return np.nan

    depth       = depth[valid].astype(float)
    temperature = temperature[valid].astype(float)
    salinity    = salinity[valid].astype(float)

    # Make sure the profile is depth-sorted (should already be, but cheap to guarantee)
    sort_idx    = np.argsort(depth)
    depth       = depth[sort_idx]
    temperature = temperature[sort_idx]
    salinity    = salinity[sort_idx]

    # If the whole profile is shallower than the reference depth, MLD is undefined here
    if depth[-1] <= ref_depth:
        return np.nan

    if lon is None or lat is None:
        raise ValueError("lon and lat must be provided")

    # Convert to TEOS-10 variables required by gsw for a physically consistent density
    SA = gsw.SA_from_SP(salinity, depth, lon=float(lon), lat=float(lat))
    CT = gsw.CT_from_pt(SA, temperature)          # potential -> Conservative Temperature
    sigma0 = gsw.sigma0(SA, CT)

    if ref_depth < depth[0]:
        return np.nan
    # Reference density interpolated to exactly ref_depth
    rho_ref = np.interp(ref_depth, depth, sigma0)

    # Only look below the reference depth for where density first exceeds the threshold
    below   = depth > ref_depth
    if below.sum() == 0:
        return np.nan

    d_s     = depth[below]
    sig_s   = sigma0[below]
    exceeds = np.where(np.abs(sig_s - rho_ref) > delta_rho)[0]

    if len(exceeds) == 0:
        return np.nan

    idx = exceeds[0]
    if idx == 0:
        return float(d_s[0])

    # Linearly interpolate between the last level below threshold and the first level
    # above it, so the MLD estimate isn't just snapped to the model's discrete levels
    d0, d1 = d_s[idx - 1], d_s[idx]
    s0, s1 = sig_s[idx - 1], sig_s[idx]
    denom  = abs(s1 - rho_ref) - abs(s0 - rho_ref)
    frac   = 0.0 if denom == 0 else (delta_rho - abs(s0 - rho_ref)) / denom
    return float(d0 + frac * (d1 - d0))

# %%
def calculate_mld_model(temperature, salinity,
                         delta_rho=0.03, ref_depth=10.0,
                         depth_dim="z_l", time_sel=None):
    """
    Vectorised wrapper around calculate_mld_profile_om3: applies the
    per-column calculation across every (time, y, x) point using
    xr.apply_ufunc + dask, so it stays lazy until .compute() is called.
    """
    if time_sel is not None:
        temperature = temperature.sel(time=time_sel)
        salinity    = salinity.sel(time=time_sel)

    # The vertical dimension can't be chunked for apply_ufunc to see a full profile
    temp_ch    = temperature.chunk({depth_dim: -1})
    salt_ch    = salinity.chunk({depth_dim: -1})
    depth_vals = temp_ch[depth_dim].values.astype(float)

    def _mld_1d(temp_col, salt_col, lon_val, lat_val):
        return calculate_mld_profile_om3(depth_vals, temp_col, salt_col,
                                          delta_rho=delta_rho, ref_depth=ref_depth,
                                          lon=lon_val, lat=lat_val)

    mld = xr.apply_ufunc(
        _mld_1d, temp_ch, salt_ch,
        salt_ch["xh"],   # check your model coordinate name
        salt_ch["yh"],
        input_core_dims=[[depth_dim], [depth_dim], [], []],
        output_dtypes=[float],
        vectorize=True,
        dask="parallelized",
    )

    mld.name = "mld"
    mld.attrs["units"] = "m"
    mld.attrs["long_name"] = "Mixed Layer Depth"
    mld.attrs["criterion"] = f"delta_sigma0 > {delta_rho} kg/m3 from {ref_depth} m"
    return mld

# %% [markdown]
# ### Load model temperature and salinity from the datastore

# %%
# Open the experiment's ESM datastore
datastore = intake.open_esm_datastore(
    esm_file,
    columns_with_iterables=[
        "variable",
        "variable_long_name",
        "variable_standard_name",
        "variable_cell_methods",
        "variable_units",
    ],
)

# select_variable() looks up by CF standard_name first, falling back to a list of
# known variable names if the catalog doesn't carry standard_name metadata.
temp_model = select_variable(
    datastore,
    temp_standard_name,
    temp_fallback_names,
    data_frequency=data_frequency,
)
salt_model = select_variable(
    datastore,
    salt_standard_name,
    salt_fallback_names,
    data_frequency=data_frequency,
)

print("Selected temperature variable:", temp_model.name, "dims:", temp_model.dims)
print("Selected salinity variable:", salt_model.name, "dims:", salt_model.dims)
# Out:
# CF-based lookup failed: ValueError('No entries found for this CF standard_name.')
# Selected variable via fallback name: thetao
# CF-based lookup failed: ValueError('No entries found for this CF standard_name.')
# Selected variable via fallback name: so
# Selected temperature variable: thetao dims: ('time', 'z_l', 'yh', 'xh')
# Selected salinity variable: so dims: ('time', 'z_l', 'yh', 'xh')

# %%
# Discover lon/lat from the catalog's grid variables (same helper as MLD.ipynb)
lon, lat = get_lon_lat_from_catalog(datastore)

# Ensure the temperature field has CF-recognisable longitude/latitude coords
try:
    _ = temp_model.cf["longitude"]
    _ = temp_model.cf["latitude"]
    print("Using existing CF longitude/latitude on temp_model.")
except KeyError:
    temp_model = temp_model.cf.assign_coords({"longitude": lon, "latitude": lat})
    salt_model = salt_model.cf.assign_coords({"longitude": lon, "latitude": lat})
    print("Attached longitude/latitude from catalog grid variables.")
# Out:
# Using existing CF longitude/latitude on temp_model.

# %% [markdown]
# ### Compute MLD from temperature and salinity

# %%
# Compute MLD across the full time series (still lazy — nothing computed yet)
mld_model = calculate_mld_model(
    temp_model,
    salt_model,
    delta_rho=delta_rho,
    ref_depth=ref_depth,
    depth_dim="z_l",
)
mld_model
# Out:
# <xarray.DataArray 'mld' (time: 792, yh: 1152, xh: 1440)> Size: 11GB
# dask.array<transpose, shape=(792, 1152, 1440), dtype=float64, chunksize=(12, 192, 160), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 6kB 1958-01-16 12:00:00 ... 2023-12-16 12:00:00
#   * yh       (yh) float64 9kB -81.58 -81.52 -81.45 -81.39 ... 89.74 89.84 89.95
#   * xh       (xh) float64 12kB -279.9 -279.6 -279.4 -279.1 ... 79.38 79.62 79.88
# Attributes:
#     units:          m
#     long_name:      Mixed Layer Depth
#     cell_methods:   area:mean z_l:mean yh:mean xh:mean time: mean
#     cell_measures:  area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  not provided
#     criterion:      delta_sigma0 > 0.03 kg/m3 from 10.0 m

# %% [markdown]
# ### Configure the averaging window

# %%
# Put model time axis on a common calendar
mld_model = mld_model.convert_calendar("proleptic_gregorian", use_cftime=True)

# Inspect full time coverage
t0 = mld_model.time.values[0]
t1 = mld_model.time.values[-1]
print("Full model time range:", t0, "→", t1)

# Decide the averaging window based on configuration 
import cftime

if averaging_mode == "full_period":
    datestart = t0
    datestop = t1
elif averaging_mode == "last_n_years":
    datestop = t1
    datelist = list(cftime.to_tuple(datestop))
    datelist[0] -= averaging_last_n_years
    datestart = cftime.datetime(*datelist, calendar=datestop.calendar)
elif averaging_mode == "fixed_period":
    if averaging_start_date is None or averaging_end_date is None:
        raise ValueError(
            "averaging_mode='fixed_period' requires averaging_start_date and averaging_end_date"
        )
    datestart = xr.cftime_range(start=averaging_start_date, periods=1,
                                 calendar="proleptic_gregorian")[0]
    datestop = xr.cftime_range(start=averaging_end_date, periods=1,
                                calendar="proleptic_gregorian")[0]
else:
    raise ValueError(f"Unknown averaging_mode: {averaging_mode!r}")

timerange = slice(datestart, datestop)
print("Averaging window:", timerange)

mld_model_window = mld_model.cf.sel(time=timerange)
print("Windowed dims:", mld_model_window.dims)
# Out:
# Full model time range: 1958-01-16 12:00:00 → 2023-12-16 12:00:00
# Averaging window: slice(cftime.datetime(2013, 12, 16, 12, 0, 0, 0, calendar='proleptic_gregorian', has_year_zero=True), cftime.DatetimeProlepticGregorian(2023, 12, 16, 12, 0, 0, 0, has_year_zero=True), None)
# Windowed dims: ('time', 'yh', 'xh')

# %%
# Load and prepare the observational product the same way
obs_mld = xr.open_dataset(obs_file)["mld_dr003"]
obs_mld.attrs["units"] = obs_mld.attrs.get("unit", obs_mld.attrs.get("units"))
# Out:
# WARNING:pint.util:Redefining 'degrees_north' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'degrees_N' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'degreesN' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'degree_north' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'degree_N' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'degreeN' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'degrees_east' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'degrees_E' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'degreesE' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'degree_east' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'degree_E' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'degreeE' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)
# WARNING:pint.util:Redefining 'gpm' (<class 'pint.delegates.txt_defparser.plain.UnitDefinition'>)

# %% [markdown]
# ## Defining spatial plot

# %%
# Blue Marble background image, so that land is rendered underneath the ocean-only MLD field (MLD has no values over land)
blue_marble = plt.imread('/g/data/ik11/grids/BlueMarble.tiff')
blue_marble_extent = (-180, 180, -90, 90)

def plot(dat, title=None, ax=None, **kwargs):
    """
    Plot a single 2D lon/lat field on a Robinson projection with a Blue Marble
    land background underneath, matching the style used throughout MLD.ipynb.

    If `ax` is not supplied, a new figure+axes is created (single-panel case).
    If `ax` is supplied, it must already be a GeoAxes with a Robinson projection
    (this is what lets us reuse this function for the side-by-side panels below).
    """
    if title is None:
        title = dat.attrs.get('long_name', dat.name)

    created_fig = False
    if ax is None:
        fig = plt.figure(figsize=(12, 6))
        ax = plt.axes(projection=ccrs.Robinson(central_longitude=-100))
        created_fig = True

    # contourf the MLD field itself, transforming from plain lon/lat into the
    # Robinson projection on the fly
    cf = dat.plot.contourf(
        ax=ax,
        transform=ccrs.PlateCarree(),
        cbar_kwargs={"label": "\n".join(wrap(f"{dat.attrs.get('long_name', dat.name)} [{dat.attrs.get('units', '')}]", 45)),
                     "fraction": 0.03, "aspect": 15, "shrink": 0.7},
        **kwargs
    )

    # Add blue marble land on top, so land shows through where MLD is NaN
    ax.imshow(
        blue_marble, extent=blue_marble_extent, transform=ccrs.PlateCarree(), origin="upper"
    )

    ax.set_title(title)
    return cf

# %%
import cartopy.crs as ccrs
import cartopy.feature as cft
from textwrap import wrap

# %% [markdown]
# ### Seasonal averaging

# %%
def seasonal_mean(da, months):
    """
    Time-weighted mean over the timesteps whose month falls in `months`
    (e.g. [1, 2, 3] for JFM). Weighting by days-in-month accounts for the
    fact that monthly means aren't all equally long.
    """
    da_m = da.where(da["time"].dt.month.isin(months), drop=True)
    w_m  = w.where(da["time"].dt.month.isin(months), drop=True)
    return da_m.weighted(w_m).mean("time")

# %%
# Weights = days in each timestep's month, computed over the same averaging
# window (mld_model_window) established earlier via `timerange`
w = mld_model_window["time"].dt.days_in_month

# Compute JFM and JAS area-weighted-in-time seasonal means for the model MLD.
# Note: this is a *temporal* seasonal mean at each grid point (still 2D in
# space), as distinct from mld_model_mean, which was a *spatial* mean at each
# timestep (still 1D in time). They answer different questions:
#   - mld_model_mean:      "how does area-averaged MLD vary over the decade?"
#   - model_JFM_mean/JAS:  "what does the MLD map look like in summer/winter, averaged over the decade?"
model_JFM_mean = seasonal_mean(mld_model_window, [1, 2, 3])
model_JAS_mean = seasonal_mean(mld_model_window, [7, 8, 9])

# %%
# Checking sizes before loading
model_JFM_mean
# Out:
# <xarray.DataArray 'mld' (yh: 1152, xh: 1440)> Size: 13MB
# dask.array<truediv, shape=(1152, 1440), dtype=float64, chunksize=(192, 160), chunktype=numpy.ndarray>
# Coordinates:
#   * yh       (yh) float64 9kB -81.58 -81.52 -81.45 -81.39 ... 89.74 89.84 89.95
#   * xh       (xh) float64 12kB -279.9 -279.6 -279.4 -279.1 ... 79.38 79.62 79.88
# Attributes:
#     units:          m
#     long_name:      Mixed Layer Depth
#     cell_methods:   area:mean z_l:mean yh:mean xh:mean time: mean
#     cell_measures:  area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  not provided
#     criterion:      delta_sigma0 > 0.03 kg/m3 from 10.0 m

# %%
model_JAS_mean
# Out:
# <xarray.DataArray 'mld' (yh: 1152, xh: 1440)> Size: 13MB
# dask.array<truediv, shape=(1152, 1440), dtype=float64, chunksize=(192, 160), chunktype=numpy.ndarray>
# Coordinates:
#   * yh       (yh) float64 9kB -81.58 -81.52 -81.45 -81.39 ... 89.74 89.84 89.95
#   * xh       (xh) float64 12kB -279.9 -279.6 -279.4 -279.1 ... 79.38 79.62 79.88
# Attributes:
#     units:          m
#     long_name:      Mixed Layer Depth
#     cell_methods:   area:mean z_l:mean yh:mean xh:mean time: mean
#     cell_measures:  area: areacello
#     time_avg_info:  average_T1,average_T2,average_DT
#     standard_name:  not provided
#     criterion:      delta_sigma0 > 0.03 kg/m3 from 10.0 m

# %% [markdown]
# **Note:** The `.compute()` below takes a little while to load. For testing purposes, I have saved copies for OM3 test4 under:
#
# `model_JFM_mean = xr.open_dataarray('/g/data/g40/kc5856/random/om3_JFM_calc_MLD_mean.nc')`
# `model_JAS_mean = xr.open_dataarray('/g/data/g40/kc5856/random/om3_JAS_calc_MLD_mean.nc')`

# %%
model_JFM_mean = model_JFM_mean.compute()
# Out:
# 2026-08-07 16:02:17,381 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:43703
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:55814 remote=tcp://127.0.0.1:43703>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-07 16:02:18,816 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:43703 -> tcp://127.0.0.1:40017
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:43703 remote=tcp://127.0.0.1:55814>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-07 16:05:42,656 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:36467
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:55764 remote=tcp://127.0.0.1:36467>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-07 16:05:42,660 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:38549
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:42996 remote=tcp://127.0.0.1:38549>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-07 16:05:42,893 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:38549 -> tcp://127.0.0.1:43877
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:38549 remote=tcp://127.0.0.1:42996>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-07 16:05:43,507 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:36467 -> tcp://127.0.0.1:43877
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:36467 remote=tcp://127.0.0.1:55764>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-07 16:05:58,198 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:43703 -> tcp://127.0.0.1:42827
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:43703 remote=tcp://127.0.0.1:55780>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-07 16:06:01,865 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:38549 -> tcp://127.0.0.1:42827
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:38549 remote=tcp://127.0.0.1:43038>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-07 16:06:09,969 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:43703
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:55780 remote=tcp://127.0.0.1:43703>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-07 16:06:09,978 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:38549
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:43038 remote=tcp://127.0.0.1:38549>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-07 16:07:50,643 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:43877 -> tcp://127.0.0.1:43703
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:43877 remote=tcp://127.0.0.1:57500>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-07 16:08:11,621 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:43877
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:57500 remote=tcp://127.0.0.1:43877>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-07 16:08:21,767 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:43877 -> tcp://127.0.0.1:36467
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:43877 remote=tcp://127.0.0.1:57478>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-07 16:08:23,978 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:43877
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:57478 remote=tcp://127.0.0.1:43877>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-07 16:11:17,263 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:38549
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:55992 remote=tcp://127.0.0.1:38549>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-07 16:11:30,869 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:38549 -> tcp://127.0.0.1:43877
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:38549 remote=tcp://127.0.0.1:55992>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-07 16:15:03,492 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:36467
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:42182 remote=tcp://127.0.0.1:36467>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-07 16:15:03,863 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:36467 -> tcp://127.0.0.1:43877
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:36467 remote=tcp://127.0.0.1:42182>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-07 16:16:27,007 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:39827 -> tcp://127.0.0.1:36467
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:39827 remote=tcp://127.0.0.1:38256>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-07 16:16:27,970 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:39827
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:38256 remote=tcp://127.0.0.1:39827>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-07 16:16:27,975 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40017
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:47542 remote=tcp://127.0.0.1:40017>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-07 16:16:32,869 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:40017 -> tcp://127.0.0.1:36467
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:40017 remote=tcp://127.0.0.1:47542>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-07 16:19:24,849 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:36467 -> tcp://127.0.0.1:43877
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:36467 remote=tcp://127.0.0.1:50780>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-07 16:19:30,545 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:36467
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:50780 remote=tcp://127.0.0.1:36467>: ConnectionResetError: [Errno 104] Connection reset by peer

# %%
model_JAS_mean = model_JAS_mean.compute()
# Out:
# 2026-08-10 10:18:49,539 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:33309 -> tcp://127.0.0.1:37881
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:33309 remote=tcp://127.0.0.1:59398>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-10 10:19:20,973 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:33309
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:59398 remote=tcp://127.0.0.1:33309>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-10 10:20:54,544 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:42543 -> tcp://127.0.0.1:42319
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:42543 remote=tcp://127.0.0.1:45108>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-10 10:20:57,481 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:42543
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:45108 remote=tcp://127.0.0.1:42543>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-10 10:27:47,897 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40321
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:44960 remote=tcp://127.0.0.1:40321>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-10 10:28:27,456 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:40321 -> tcp://127.0.0.1:33309
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:40321 remote=tcp://127.0.0.1:44960>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-10 10:28:42,613 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:42319 -> tcp://127.0.0.1:33517
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:42319 remote=tcp://127.0.0.1:57290>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-10 10:28:32,568 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:42319
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:57290 remote=tcp://127.0.0.1:42319>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-10 10:33:05,576 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:40321
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:34758 remote=tcp://127.0.0.1:40321>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-10 10:33:27,009 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:42543
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:45070 remote=tcp://127.0.0.1:42543>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-10 10:33:40,968 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:42543 -> tcp://127.0.0.1:33517
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:42543 remote=tcp://127.0.0.1:45070>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-10 10:34:17,700 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:40321 -> tcp://127.0.0.1:37881
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:40321 remote=tcp://127.0.0.1:34758>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-10 10:35:20,063 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:37881
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:55528 remote=tcp://127.0.0.1:37881>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-10 10:35:24,159 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:37881 -> tcp://127.0.0.1:42319
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:37881 remote=tcp://127.0.0.1:55528>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-10 10:37:48,569 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:42543 -> tcp://127.0.0.1:33517
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:42543 remote=tcp://127.0.0.1:44548>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-10 10:37:55,757 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:42543
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:44548 remote=tcp://127.0.0.1:42543>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-10 10:38:14,624 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:33309 -> tcp://127.0.0.1:42319
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:33309 remote=tcp://127.0.0.1:59416>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-10 10:38:27,740 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:33309
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:59416 remote=tcp://127.0.0.1:33309>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-10 10:38:31,214 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:42543
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:41302 remote=tcp://127.0.0.1:42543>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-10 10:38:38,966 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:42543 -> tcp://127.0.0.1:42319
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:42543 remote=tcp://127.0.0.1:41302>: TimeoutError: [Errno 110] Connection timed out
# 2026-08-10 10:39:09,389 - distributed.worker - ERROR - Worker stream died during communication: tcp://127.0.0.1:42319
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2081, in gather_dep
#     response = await get_data_from_worker(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 2887, in get_data_from_worker
#     response = await send_recv(
#                ^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/core.py", line 1018, in send_recv
#     response = await comm.read(deserializers=deserializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) Ephemeral Worker->Worker for gather local=tcp://127.0.0.1:57246 remote=tcp://127.0.0.1:42319>: ConnectionResetError: [Errno 104] Connection reset by peer
# 2026-08-10 10:39:18,723 - distributed.worker - ERROR - failed during get data with tcp://127.0.0.1:42319 -> tcp://127.0.0.1:33309
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 861, in _read_to_buffer
#     bytes_read = self.read_from_fd(buf)
#                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/tornado/iostream.py", line 1113, in read_from_fd
#     return self.socket.recv_into(buf, len(buf))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TimeoutError: [Errno 110] Connection timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/worker.py", line 1803, in get_data
#     response = await comm.read(deserializers=serializers)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 237, in read
#     convert_stream_closed_error(self, e)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-26.07/lib/python3.12/site-packages/distributed/comm/tcp.py", line 143, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed)  local=tcp://127.0.0.1:42319 remote=tcp://127.0.0.1:57246>: TimeoutError: [Errno 110] Connection timed out

# %% [markdown]
# ## Plotting

# %%
plot(model_JFM_mean,
    levels=51,
    vmin=0,
    vmax=500,
    extend="max",
    cmap='viridis',
    title=f"{mld_model_window.attrs['long_name']} JFM "
          f"{mld_model_window.time.values[0].strftime('%Y-%m-%d')} - "
          f"{mld_model_window.time.values[-1].strftime('%Y-%m-%d')} mean\nin {model_name} (calculated)"
    )
# mkmd.savefig(plt.gcf(), "Mixed Layer Depth: Model JFM (manual calc)",
#              "Ocean Mixed Layer Depth JFM, calculated manually from temperature and salinity. "
#              "GitHub issue: [#38](https://github.com/ACCESS-Community-Hub/access-om3-paper-1/issues/38)")

# %%
plot(model_JAS_mean,
    levels=51,
    vmin=0,
    vmax=500,
    extend="max",
    cmap='viridis',
    title=f"{mld_model_window.attrs['long_name']} JAS "
          f"{mld_model_window.time.values[0].strftime('%Y-%m-%d')} - "
          f"{mld_model_window.time.values[-1].strftime('%Y-%m-%d')} mean\nin {model_name} (calculated)"
     )
# mkmd.savefig(plt.gcf(), "Mixed Layer Depth: Model JAS (manual calc)",
#              "Ocean Mixed Layer Depth JAS, calculated manually from temperature and salinity. "
#              "GitHub issue: [#38](https://github.com/ACCESS-Community-Hub/access-om3-paper-1/issues/38)")

# %%
# TODO: append copy of westernmost data to eastern end to avoid gap in plot
# (same caveat noted in MLD.ipynb — DeBoyerMontegut obs has a longitude seam)

# DeBoyerMontegut is a 12-month climatology, so JFM/JAS means are a simple
# unweighted mean over the relevant 3 climatological months, not a
# days-in-month-weighted mean over many years like the model side above
obs_JFM_mean = obs_mld.isel(time=[0, 1, 2]).mean('time').load()
obs_JAS_mean = obs_mld.isel(time=[6, 7, 8]).mean('time').load()

# %%
plot(obs_JFM_mean,
    levels=51,
    vmin=0,
    vmax=500,
    extend="max",
    cmap='viridis',
    title="Observed mixed layer depth JFM mean (DeBoyer Montegut, 2023)"
    )
# mkmd.savefig(plt.gcf(), "Mixed Layer Depth: Observed JFM", # Don't need to save this because it should already be done in MLD.ipynb
#              "Observed ocean Mixed Layer Depth JFM. GitHub issue: "
#              "[#38](https://github.com/ACCESS-Community-Hub/access-om3-paper-1/issues/38)")

# %%
plot(obs_JAS_mean,
    levels=51,
    vmin=0,
    vmax=500,
    extend="max",
    cmap='viridis',
    title="Observed mixed layer depth JAS mean (DeBoyer Montegut, 2023)"
    )
# mkmd.savefig(plt.gcf(), "Mixed Layer Depth: Observed JAS", # Don't need to save this because it should already be done in MLD.ipynb
#              "Observed ocean Mixed Layer Depth JAS. GitHub issue: "
#              "[#38](https://github.com/ACCESS-Community-Hub/access-om3-paper-1/issues/38)")

# %% [markdown]
# ### Side-by-side comparison: model vs observations

# %%
# Two-panel figure: model (left) and obs (right), sharing a Robinson projection
# and the same colour scale/levels, so the maps are directly comparable by eye
fig, (ax_model, ax_obs) = plt.subplots(
    1, 2, figsize=(20, 6),
    subplot_kw={"projection": ccrs.Robinson(central_longitude=-100)}
)

plot(model_JFM_mean,
     ax=ax_model,
     levels=51, vmin=0, vmax=500, extend="max", cmap='viridis',
     title=f"Model (calculated), {model_name}")

plot(obs_JFM_mean,
     ax=ax_obs,
     levels=51, vmin=0, vmax=500, extend="max", cmap='viridis',
     title="Observed (DeBoyer Montegut, 2023)")

fig.suptitle(
    f"Mixed Layer Depth, JFM mean\n"
    f"Model: {mld_model_window.time.values[0].strftime('%Y-%m-%d')} - "
    f"{mld_model_window.time.values[-1].strftime('%Y-%m-%d')}",
    fontsize=14
)
plt.tight_layout()

# mkmd.savefig(fig, "Mixed Layer Depth: Model vs Observed JFM (side by side)",
#              "Side-by-side comparison of calculated model MLD and DeBoyer Montegut (2023) "
#              "observed MLD, JFM mean. GitHub issue: "
#              "[#38](https://github.com/ACCESS-Community-Hub/access-om3-paper-1/issues/38)")

# %%
fig, (ax_model, ax_obs) = plt.subplots(
    1, 2, figsize=(20, 6),
    subplot_kw={"projection": ccrs.Robinson(central_longitude=-100)}
)

plot(model_JAS_mean,
     ax=ax_model,
     levels=51, vmin=0, vmax=500, extend="max", cmap='viridis',
     title=f"Model (calculated), {model_name}")

plot(obs_JAS_mean,
     ax=ax_obs,
     levels=51, vmin=0, vmax=500, extend="max", cmap='viridis',
     title="Observed (DeBoyer Montegut, 2023)")

fig.suptitle(
    f"Mixed Layer Depth, JAS mean\n"
    f"Model: {mld_model_window.time.values[0].strftime('%Y-%m-%d')} - "
    f"{mld_model_window.time.values[-1].strftime('%Y-%m-%d')}",
    fontsize=14
)
plt.tight_layout()

# mkmd.savefig(fig, "Mixed Layer Depth: Model vs Observed JAS (side by side)",
#              "Side-by-side comparison of calculated model MLD and DeBoyer Montegut (2023) "
#              "observed MLD, JAS mean. GitHub issue: "
#              "[#38](https://github.com/ACCESS-Community-Hub/access-om3-paper-1/issues/38)")

# %% [markdown]
# # Anomaly between Obs and OM3

# %%
from scipy.interpolate import interp1d
import cartopy.feature as cfeature

# %%
# Creating new spatial plot to look nice with anomalies
def plot_anomaly(dat, title=None, ax=None, **kwargs):
    """
    Plot a single 2D lon/lat field on a Robinson projection with land shown
    as light grey with a black coastline, matching the style used throughout
    MLD.ipynb.
    If `ax` is not supplied, a new figure+axes is created (single-panel case).
    If `ax` is supplied, it must already be a GeoAxes with a Robinson projection
    (this is what lets us reuse this function for the side-by-side panels below).
    """
    if title is None:
        title = dat.attrs.get('long_name', dat.name)
    created_fig = False
    if ax is None:
        fig = plt.figure(figsize=(12, 6))
        ax = plt.axes(projection=ccrs.Robinson(central_longitude=-100))
        created_fig = True
    # contourf the MLD field itself, transforming from plain lon/lat into the
    # Robinson projection on the fly
    cf = dat.plot.contourf(
        ax=ax,
        transform=ccrs.PlateCarree(),
        cbar_kwargs={"label": "\n".join(wrap(f"{dat.attrs.get('long_name', dat.name)} [{dat.attrs.get('units', '')}]", 45)),
                     "fraction": 0.03, "aspect": 15, "shrink": 0.7},
        **kwargs
    )
    # Add light grey land fill with a black coastline on top, so land shows
    # through where MLD is NaN
    ax.add_feature(cfeature.LAND, zorder=1, facecolor="lightgrey")
    ax.add_feature(cfeature.COASTLINE, zorder=2, edgecolor="black", linewidth=0.8)
    ax.set_title(title)
    return cf

# %%
# Renaming coordinates to match obs
model_JFM_mean_new = model_JFM_mean.rename({'xh': 'lon', 'yh': 'lat'})
model_JAS_mean_new = model_JAS_mean.rename({'xh': 'lon', 'yh': 'lat'})

# Convert model longitude to [-180, 180]
model_JFM_mean_new = model_JFM_mean_new.assign_coords(lon=((model_JFM_mean_new.lon + 180) % 360) - 180)
model_JAS_mean_new = model_JAS_mean_new.assign_coords(lon=((model_JAS_mean_new.lon + 180) % 360) - 180)

# Sort after wrapping (important for interp)
model_JFM_mean_new = model_JFM_mean_new.sortby('lon')
model_JAS_mean_new = model_JAS_mean_new.sortby('lon')

# Interpolate
model_JFM_mean_interp = model_JFM_mean_new.interp(lat=obs_JFM_mean.lat, lon=obs_JFM_mean.lon)
model_JAS_mean_interp = model_JAS_mean_new.interp(lat=obs_JAS_mean.lat, lon=obs_JAS_mean.lon)

# %%
anomaly_JFM = model_JFM_mean_interp - obs_JFM_mean
anomaly_JAS = model_JAS_mean_interp - obs_JAS_mean

# %%
# Two-panel figure: model (left) and obs (right), sharing a Robinson projection
# and the same colour scale/levels, so the maps are directly comparable by eye
fig, (ax_model, ax_obs) = plt.subplots(
    1, 2, figsize=(20, 6),
    subplot_kw={"projection": ccrs.Robinson(central_longitude=-100)}
)

cf_model = plot_anomaly(anomaly_JFM,
     ax=ax_model,
     levels=51, vmin=-300, vmax=300, extend="max", cmap='RdBu_r',
     title=f"Model {model_name} (calculated) - Obs")
cf_model.colorbar.set_label("MLD anomaly [m]")

cf_obs = plot(obs_JFM_mean,
     ax=ax_obs,
     levels=51, vmin=0, vmax=500, extend="max", cmap='viridis',
     title="Observed (DeBoyer Montegut, 2023)")
cf_obs.colorbar.set_label("MLD [m]")

fig.suptitle(
    f"Mixed Layer Depth, JFM mean\n"
    f"Model: {mld_model_window.time.values[0].strftime('%Y-%m-%d')} - "
    f"{mld_model_window.time.values[-1].strftime('%Y-%m-%d')}",
    fontsize=14
)
plt.tight_layout()

# mkmd.savefig(fig, "Mixed Layer Depth: Model Anomaly vs Observed JFM (side by side)",
#              "Side-by-side comparison of calculated model MLD anomaly and DeBoyer Montegut (2023) "
#              "observed MLD, JFM mean. GitHub issue: "
#              "[#38](https://github.com/ACCESS-Community-Hub/access-om3-paper-1/issues/38)")

# %%
# Two-panel figure: model (left) and obs (right), sharing a Robinson projection
# and the same colour scale/levels, so the maps are directly comparable by eye
fig, (ax_model, ax_obs) = plt.subplots(
    1, 2, figsize=(20, 6),
    subplot_kw={"projection": ccrs.Robinson(central_longitude=-100)}
)

cf_model = plot_anomaly(anomaly_JAS,
     ax=ax_model,
     levels=51, vmin=-300, vmax=300, extend="max", cmap='RdBu_r',
     title=f"Model {model_name} (calculated) - Obs")
cf_model.colorbar.set_label("MLD anomaly [m]")

cf_obs = plot(obs_JAS_mean,
     ax=ax_obs,
     levels=51, vmin=0, vmax=500, extend="max", cmap='viridis',
     title="Observed (DeBoyer Montegut, 2023)")
cf_obs.colorbar.set_label("MLD [m]")

fig.suptitle(
    f"Mixed Layer Depth, JAS mean\n"
    f"Model: {mld_model_window.time.values[0].strftime('%Y-%m-%d')} - "
    f"{mld_model_window.time.values[-1].strftime('%Y-%m-%d')}",
    fontsize=14
)
plt.tight_layout()

# mkmd.savefig(fig, "Mixed Layer Depth: Model Anomaly vs Observed JAS (side by side)",
#              "Side-by-side comparison of calculated model MLD anomaly and DeBoyer Montegut (2023) "
#              "observed MLD, JAS mean. GitHub issue: "
#              "[#38](https://github.com/ACCESS-Community-Hub/access-om3-paper-1/issues/38)")
